# %% [markdown]
# <a href="https://colab.research.google.com/github/shreythapar/ML_Dataset/blob/main/ML_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt

df2 = pd.read_csv("https://raw.githubusercontent.com/shreythapar/ML_Dataset/main/Disease%20Prediction.csv?token=APJ435FPHHD6BXZTUI7WEQTA6WMV4", 
                  usecols=["itching", "skin_rash", "prognosis", "cough", "nodal_skin_eruptions", "joint_pain"])

# plt.figure(figsize = (2, 20))
plt.scatter(df2['itching'], df2['prognosis'])
plt.xlabel('Itching')
plt.ylabel('Skin Rash')
plt.title("Itching v/s Skin Rash")
plt.show()

# %%
plt.figure(figsize = (4, 4))
plt.bar(df2['itching'], df2['skin_rash'])
plt.xlabel('Itching')
plt.ylabel('Skin Rash')
plt.title("Itching v/s Skin Rash")
plt.show()

# %%
# plt.figure(figsize = (4, 4))
plt.hist(df2['itching'], bins = 15)
plt.title("Itching v/s Skin Rash")
plt.xlabel('Itching')
plt.ylabel('Skin Rash')
plt.show()

# %%
import seaborn as sns
sns.countplot(y = df2['prognosis'], data=df2)
sns.set(rc={'figure.figsize':(61.7,8.27)})

# %%
plt.figure(figsize = (10, 10))
sns.boxplot(x = df2['cough'], y = df2['prognosis'], showfliers = True)

# %%
plt.figure(figsize = (10, 10))
sns.boxplot(x = df2['cough'], y = df2['prognosis'], showfliers = False)

# %%
sns.boxplot(x=df2['joint_pain'])
