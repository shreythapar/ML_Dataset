# %% [markdown]
# <a href="https://colab.research.google.com/github/shreythapar/ML_Dataset/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/shreythapar/ML_Dataset/main/Disease%20Prediction.csv?token=APJ435FPHHD6BXZTUI7WEQTA6WMV4")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   itching                983 non-null    float64
#  1   skin_rash              981 non-null    float64
#  2   nodal_skin_eruptions   974 non-null    float64
#  3   continuous_sneezing    965 non-null    float64
#  4   shivering              950 non-null    float64
#  5   chills                 980 non-null    float64
#  6   joint_pain             997 non-null    float64
#  7   stomach_pain           982 non-null    float64
#  8   acidity                977 non-null    float64
#  9   ulcers_on_tongue       992 non-null    float64
#  10  muscle_wasting         999 non-null    int64
#  11  vomiting               980 non-null    float64
#  12  burning_micturition    987 non-null    float64
#  13  spotting_ urination    991 non-null    float64
# ...

# %%
df.size
# Out:
# 26973

# %%
df.shape
# Out:
# (999, 27)

# %%
df.dtypes
# Out:
# itching                  float64
# skin_rash                float64
# nodal_skin_eruptions     float64
# continuous_sneezing      float64
# shivering                float64
# chills                   float64
# joint_pain               float64
# stomach_pain             float64
# acidity                  float64
# ulcers_on_tongue         float64
# muscle_wasting             int64
# vomiting                 float64
# burning_micturition      float64
# spotting_ urination      float64
# fatigue                  float64
# weight_gain                int64
# anxiety                  float64
# cold_hands_and_feets     float64
# mood_swings              float64
# weight_loss              float64
# restlessness             float64
# lethargy                 float64
# patches_in_throat        float64
# irregular_sugar_level    float64
# cough                      int64
# high_fever               float64
# prognosis                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# itching                  16
# skin_rash                18
# nodal_skin_eruptions     25
# continuous_sneezing      34
# shivering                49
# chills                   19
# joint_pain                2
# stomach_pain             17
# acidity                  22
# ulcers_on_tongue          7
# muscle_wasting            0
# vomiting                 19
# burning_micturition      12
# spotting_ urination       8
# fatigue                   7
# weight_gain               0
# anxiety                  17
# cold_hands_and_feets      5
# mood_swings               9
# weight_loss              11
# restlessness             26
# lethargy                  7
# patches_in_throat        16
# irregular_sugar_level    12
# cough                     0
# high_fever               24
# prognosis                 0
# dtype: int64

# %%
df["itching"].fillna(df["itching"].mode()[0], inplace = True)
df["acidity"].fillna(df["acidity"].mode()[0], inplace = True)
df["fatigue"].fillna(df["fatigue"].mode()[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# itching                   0
# skin_rash                18
# nodal_skin_eruptions     25
# continuous_sneezing      34
# shivering                49
# chills                   19
# joint_pain                2
# stomach_pain             17
# acidity                   0
# ulcers_on_tongue          7
# muscle_wasting            0
# vomiting                 19
# burning_micturition      12
# spotting_ urination       8
# fatigue                   0
# weight_gain               0
# anxiety                  17
# cold_hands_and_feets      5
# mood_swings               9
# weight_loss              11
# restlessness             26
# lethargy                  7
# patches_in_throat        16
# irregular_sugar_level    12
# cough                     0
# high_fever               24
# prognosis                 0
# dtype: int64

# %%
df.head(10)
# Out:
#    itching  skin_rash  ...  high_fever         prognosis
# 0      1.0        1.0  ...         NaN  Fungal infection
# 1      0.0        1.0  ...         NaN  Fungal infection
# 2      1.0        0.0  ...         NaN  Fungal infection
# 3      1.0        1.0  ...         NaN  Fungal infection
# 4      1.0        1.0  ...         NaN  Fungal infection
# 5      0.0        1.0  ...         0.0  Fungal infection
# 6      1.0        0.0  ...         0.0  Fungal infection
# 7      1.0        1.0  ...         0.0  Fungal infection
# 8      1.0        1.0  ...         0.0  Fungal infection
# 9      1.0        1.0  ...         0.0  Fungal infection
#
# [10 rows x 27 columns]

# %%
df.tail()
# Out:
#      itching  skin_rash  nodal_skin_eruptions  ...  cough  high_fever  prognosis
# 994      0.0        NaN                   0.0  ...      0         1.0     Dengue
# 995      0.0        NaN                   0.0  ...      0         1.0     Dengue
# 996      0.0        1.0                   0.0  ...      0         1.0     Dengue
# 997      0.0        1.0                   0.0  ...      0         1.0     Dengue
# 998      0.0        1.0                   0.0  ...      0         1.0     Dengue
#
# [5 rows x 27 columns]
